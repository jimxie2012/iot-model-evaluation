# %%
import time,json,os
import numpy as np
import pandas as pd
from inference import *
from common import preprocess,get_csv_files,g_analyse_path,g_ds_sample_path,g_model_path
from warnings import filterwarnings
filterwarnings("ignore") 
np.set_printoptions(suppress=True)
pd.set_option('display.float_format',lambda x : '%.8f' % x)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 . connected.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         41 secs
# H2O_cluster_timezone:       UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.34.0.3
# H2O_cluster_version_age:    1 month and 23 days
# H2O_cluster_name:           root
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    9.97 Gb
# H2O_cluster_total_cores:    22
# H2O_cluster_allowed_cores:  22
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# H2O_API_Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
# Python_version:             3.7.9 final
# --------------------------  ------------------------------------------------------------------

# %%
os.system("mkdir -p %s"%g_analyse_path)
csv_list = []
get_csv_files(g_ds_sample_path,csv_list)
csv_list.sort()
all_models = get_all_models()

# %%
all_result = []
for item in json.loads(all_models.to_json(orient="records")):
    model_name = item['model_name']
    dataset = item['dataset']
    model_file = item['model_file']
    if model_file.find("PSVM_model_python") >= 0:
        continue
    print(model_name,dataset)
    perf = CJPerformance(model_file)
    for csv in csv_list:
        valid_set = os.path.splitext(os.path.basename(csv))[0]
        print("inference ","%s(%s)"%(model_name,dataset), "validation set %s"%valid_set)
        result = perf.Test(csv,True)
        result['model'] = model_name
        result['train'] = dataset
        result['valid'] = valid_set
        print(result)
        all_result.append(result)
df_result = pd.DataFrame(all_result)
# Out:
# xgboost s-1-2-0
# inference  xgboost(s-1-2-0) validation set s-0-1-0
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix           [[0, 185997], [0, 64003]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                    0.256012
# precision                                   0.256012
# auc                                              0.5
# log_loss                                 25.69703006
# f1_score                                  0.40765853
# fbeta_score                               0.30076513
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-0-1-0
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-0-1-1
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix            [[0, 38471], [0, 11529]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                     0.23058
# precision                                    0.23058
# auc                                              0.5
# log_loss                                 26.57544056
# f1_score                                  0.37475012
# fbeta_score                               0.27251583
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-0-1-1
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-0-1-2
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix           [[0, 186218], [0, 63782]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                    0.255128
# precision                                   0.255128
# auc                                              0.5
# log_loss                                 25.72756305
# f1_score                                  0.40653702
# fbeta_score                               0.29978887
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-0-1-2
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-0-1-3
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                          [[0, 325155], [39, 174806]]
# roc_curve           ([0.0, 1.0, 1.0], [0.0, 0.9997769452944036, 1....
# recall                                                     0.99977695
# mcc                                                       -0.01204434
# accuracy                                                     0.349612
# precision                                                  0.34963927
# auc                                                        0.49988847
# log_loss                                                  22.46412569
# f1_score                                                   0.51809261
# fbeta_score                                                0.40191034
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-0-1-3
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-0-2-0
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix           [[0, 185894], [0, 64106]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                    0.256424
# precision                                   0.256424
# auc                                              0.5
# log_loss                                 25.68279976
# f1_score                                  0.40818068
# fbeta_score                               0.30121999
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-0-2-0
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-0-2-1
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix            [[0, 38555], [0, 11445]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                      0.2289
# precision                                     0.2289
# auc                                              0.5
# log_loss                                 26.63346705
# f1_score                                  0.37252828
# fbeta_score                               0.27063775
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-0-2-1
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-0-2-2
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix           [[0, 185909], [0, 64091]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                    0.256364
# precision                                   0.256364
# auc                                              0.5
# log_loss                                 25.68487213
# f1_score                                  0.40810466
# fbeta_score                               0.30115375
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-0-2-2
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-0-2-3
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                          [[0, 325155], [39, 174806]]
# roc_curve           ([0.0, 1.0, 1.0], [0.0, 0.9997769452944036, 1....
# recall                                                     0.99977695
# mcc                                                       -0.01204434
# accuracy                                                     0.349612
# precision                                                  0.34963927
# auc                                                        0.49988847
# log_loss                                                  22.46412569
# f1_score                                                   0.51809261
# fbeta_score                                                0.40191034
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-0-2-3
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-0-3-0
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                        [[10, 137846], [141, 112003]]
# roc_curve           ([0.0, 0.999927460538533, 1.0], [0.0, 0.998742...
# recall                                                     0.99874269
# mcc                                                       -0.02398328
# accuracy                                                     0.448052
# precision                                                  0.44828276
# auc                                                        0.49940761
# log_loss                                                  19.06404944
# f1_score                                                   0.61881307
# fbeta_score                                                0.50381903
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-0-3-0
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-0-3-1
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                            [[2, 25389], [38, 24571]]
# roc_curve           ([0.0, 0.9999212319325745, 1.0], [0.0, 0.99845...
# recall                                                     0.99845585
# mcc                                                       -0.02591174
# accuracy                                                      0.49146
# precision                                                  0.49181345
# auc                                                        0.49926731
# log_loss                                                  17.56475537
# f1_score                                                    0.6590138
# fbeta_score                                                0.54736265
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-0-3-1
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-0-3-2
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                        [[12, 138015], [127, 111846]]
# roc_curve           ([0.0, 0.9999130604881653, 1.0], [0.0, 0.99886...
# recall                                                      0.9988658
# mcc                                                       -0.02209213
# accuracy                                                     0.447432
# precision                                                  0.44763288
# auc                                                        0.49947637
# log_loss                                                  19.08546402
# f1_score                                                   0.61821719
# fbeta_score                                                0.50316848
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-0-3-2
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-0-3-3
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                          [[0, 325155], [39, 174806]]
# roc_curve           ([0.0, 1.0, 1.0], [0.0, 0.9997769452944036, 1....
# recall                                                     0.99977695
# mcc                                                       -0.01204434
# accuracy                                                     0.349612
# precision                                                  0.34963927
# auc                                                        0.49988847
# log_loss                                                  22.46412569
# f1_score                                                   0.51809261
# fbeta_score                                                0.40191034
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-0-3-3
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-0-4-0
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                         [[8, 137809], [121, 112062]]
# roc_curve           ([0.0, 0.9999419520088233, 1.0], [0.0, 0.99892...
# recall                                                     0.99892141
# mcc                                                        -0.0223509
# accuracy                                                      0.44828
# precision                                                  0.44847942
# auc                                                        0.49948973
# log_loss                                                  19.05617448
# f1_score                                                   0.61903473
# fbeta_score                                                0.50402684
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-0-4-0
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-0-4-1
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                            [[2, 25342], [17, 24639]]
# roc_curve           ([0.0, 0.9999210858585859, 1.0], [0.0, 0.99931...
# recall                                                     0.99931051
# mcc                                                       -0.01566237
# accuracy                                                      0.49282
# precision                                                  0.49296733
# auc                                                        0.49969471
# log_loss                                                  17.51778188
# f1_score                                                   0.66023554
# fbeta_score                                                0.54855731
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-0-4-1
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-0-4-2
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                        [[11, 137802], [123, 112064]]
# roc_curve           ([0.0, 0.9999201816954859, 1.0], [0.0, 0.99890...
# recall                                                     0.99890362
# mcc                                                       -0.02184468
# accuracy                                                       0.4483
# precision                                                  0.44849639
# auc                                                        0.49949172
# log_loss                                                  19.05548368
# f1_score                                                   0.61904749
# fbeta_score                                                0.50404309
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-0-4-2
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-0-4-3
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                          [[0, 325155], [39, 174806]]
# roc_curve           ([0.0, 1.0, 1.0], [0.0, 0.9997769452944036, 1....
# recall                                                     0.99977695
# mcc                                                       -0.01204434
# accuracy                                                     0.349612
# precision                                                  0.34963927
# auc                                                        0.49988847
# log_loss                                                  22.46412569
# f1_score                                                   0.51809261
# fbeta_score                                                0.40191034
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-0-4-3
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-1-1-0
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                           [[109, 8704], [1, 241186]]
# roc_curve           ([0.0, 0.9876319074095087, 1.0], [0.0, 0.99999...
# recall                                                     0.99999585
# mcc                                                        0.10872394
# accuracy                                                      0.96518
# precision                                                  0.96516867
# auc                                                        0.50618197
# log_loss                                                   1.20266803
# f1_score                                                   0.98227366
# fbeta_score                                                0.97193868
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-1-1-0
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-1-1-1
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                           [[23, 1313], [393, 48271]]
# roc_curve           ([0.0, 0.9827844311377245, 1.0], [0.0, 0.99192...
# recall                                                     0.99192422
# mcc                                                        0.01622653
# accuracy                                                      0.96588
# precision                                                  0.97351968
# auc                                                        0.50456989
# log_loss                                                   1.17848405
# f1_score                                                   0.98263578
# fbeta_score                                                0.97714575
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-1-1-1
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-1-1-2
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                            [[12, 8937], [3, 241048]]
# roc_curve           ([0.0, 0.9986590680522963, 1.0], [0.0, 0.99998...
# recall                                                     0.99998755
# mcc                                                         0.0318637
# accuracy                                                      0.96424
# precision                                                  0.96424985
# auc                                                        0.50066424
# log_loss                                                   1.23513523
# f1_score                                                    0.9817936
# fbeta_score                                                0.97119157
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-1-1-2
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-1-1-3
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                           [[38, 70471], [1, 429490]]
# roc_curve           ([0.0, 0.9994610617084344, 1.0], [0.0, 0.99999...
# recall                                                     0.99999767
# mcc                                                        0.02114743
# accuracy                                                     0.859056
# precision                                                  0.85904701
# auc                                                         0.5002683
# log_loss                                                     4.868146
# f1_score                                                   0.92417898
# fbeta_score                                                0.88396619
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-1-1-3
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-1-2-0
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                           [[8336, 577], [9, 241078]]
# roc_curve           ([0.0, 0.0647369011556154, 1.0], [0.0, 0.99996...
# recall                                                     0.99996267
# mcc                                                        0.96539323
# accuracy                                                     0.997656
# precision                                                   0.9976123
# auc                                                        0.96761288
# log_loss                                                   0.08096074
# f1_score                                                    0.9987861
# fbeta_score                                                0.99808149
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-1-2-0
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-1-2-1
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                          [[225, 1160], [411, 48204]]
# roc_curve           ([0.0, 0.8375451263537906, 1.0], [0.0, 0.99154...
# recall                                                     0.99154582
# mcc                                                        0.22552723
# accuracy                                                      0.96858
# precision                                                  0.97650109
# auc                                                        0.57700035
# log_loss                                                    1.0852269
# f1_score                                                   0.98396595
# fbeta_score                                                 0.9794734
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-1-2-1
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-1-2-2
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                            [[11, 8810], [2, 241177]]
# roc_curve           ([0.0, 0.9987529758530779, 1.0], [0.0, 0.99999...
# recall                                                     0.99999171
# mcc                                                        0.03169388
# accuracy                                                     0.964752
# precision                                                  0.96475817
# auc                                                        0.50061937
# log_loss                                                   1.21745097
# f1_score                                                   0.98205902
# fbeta_score                                                0.97160484
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-1-2-2
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-1-2-3
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                           [[15, 70496], [1, 429488]]
# roc_curve           ([0.0, 0.9997872672348995, 1.0], [0.0, 0.99999...
# recall                                                     0.99999767
# mcc                                                        0.01294557
# accuracy                                                     0.859006
# precision                                                  0.85900349
# auc                                                         0.5001052
# log_loss                                                   4.86987298
# f1_score                                                   0.92415379
# fbeta_score                                                0.88392932
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-1-2-3
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-1-3-0
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                           [[22, 67978], [2, 181998]]
# roc_curve           ([0.0, 0.9996764705882353, 1.0], [0.0, 0.99998...
# recall                                                     0.99998901
# mcc                                                         0.0141952
# accuracy                                                      0.72808
# precision                                                  0.72806189
# auc                                                        0.50015627
# log_loss                                                    9.3920015
# f1_score                                                   0.84263015
# fbeta_score                                                0.76993563
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-1-3-0
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-1-3-1
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                             [[6, 23034], [0, 26960]]
# roc_curve           ([0.0, 0.9997395833333333, 1.0], [0.0, 1.0, 1....
# recall                                                            1.0
# mcc                                                        0.01185046
# accuracy                                                      0.53932
# precision                                                  0.53926471
# auc                                                        0.50013021
# log_loss                                                  15.91169187
# f1_score                                                   0.70067833
# fbeta_score                                                0.59400007
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-1-3-1
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-1-3-2
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                           [[26, 68023], [2, 181949]]
# roc_curve           ([0.0, 0.9996179223794619, 1.0], [0.0, 0.99998...
# recall                                                     0.99998901
# mcc                                                        0.01560765
# accuracy                                                       0.7279
# precision                                                  0.72787752
# auc                                                        0.50018554
# log_loss                                                   9.39821862
# f1_score                                                   0.84250665
# fbeta_score                                                0.76977067
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-1-3-2
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-1-3-3
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                           [[33, 70332], [0, 429635]]
# roc_curve           ([0.0, 0.9995310168407588, 1.0], [0.0, 1.0, 1....
# recall                                                            1.0
# mcc                                                         0.0200751
# accuracy                                                     0.859336
# precision                                                  0.85932672
# auc                                                        0.50023449
# log_loss                                                   4.85847492
# f1_score                                                   0.92434182
# fbeta_score                                                0.88420348
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-1-3-3
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-1-4-0
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                           [[18, 67693], [0, 182289]]
# roc_curve           ([0.0, 0.99973416431599, 1.0], [0.0, 1.0, 1.0]...
# recall                                                            1.0
# mcc                                                        0.01392299
# accuracy                                                     0.729228
# precision                                                   0.7292085
# auc                                                        0.50013292
# log_loss                                                   9.35235007
# f1_score                                                   0.84340148
# fbeta_score                                                0.77096252
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-1-4-0
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-1-4-1
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                             [[9, 23122], [0, 26869]]
# roc_curve           ([0.0, 0.9996109117634343, 1.0], [0.0, 1.0, 1....
# recall                                                            1.0
# mcc                                                        0.01446119
# accuracy                                                      0.53756
# precision                                                  0.53747675
# auc                                                        0.50019454
# log_loss                                                  15.97248152
# f1_score                                                   0.69916732
# fbeta_score                                                0.59226391
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-1-4-1
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-1-4-2
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                           [[50, 68047], [2, 181901]]
# roc_curve           ([0.0, 0.9992657532637268, 1.0], [0.0, 0.99998...
# recall                                                     0.99998901
# mcc                                                        0.02232785
# accuracy                                                     0.727804
# precision                                                  0.72775537
# auc                                                        0.50036163
# log_loss                                                   9.40153442
# f1_score                                                   0.84242482
# fbeta_score                                                0.76966138
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-1-4-2
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-1-4-3
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                           [[44, 70455], [4, 429497]]
# roc_curve           ([0.0, 0.9993758776720237, 1.0], [0.0, 0.99999...
# recall                                                     0.99999069
# mcc                                                        0.02183882
# accuracy                                                     0.859082
# precision                                                  0.85907647
# auc                                                         0.5003074
# log_loss                                                   4.86724796
# f1_score                                                   0.92419305
# fbeta_score                                                0.88399006
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-1-4-3
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-2-1-0
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix          [[0, 125329], [0, 124671]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                    0.498684
# precision                                   0.498684
# auc                                              0.5
# log_loss                                 17.31524208
# f1_score                                  0.66549586
# fbeta_score                               0.55425542
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-2-1-0
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-2-1-1
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                         [[10013, 15078], [1, 24908]]
# roc_curve           ([0.0, 0.6009326053166474, 1.0], [0.0, 0.99995...
# recall                                                     0.99995985
# mcc                                                        0.49851922
# accuracy                                                      0.69842
# precision                                                  0.62291802
# auc                                                        0.69951362
# log_loss                                                  10.41644531
# f1_score                                                   0.76764003
# fbeta_score                                                0.67372453
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-2-1-1
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-2-1-2
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix          [[0, 124800], [0, 125200]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                      0.5008
# precision                                     0.5008
# auc                                              0.5
# log_loss                                 17.24215634
# f1_score                                   0.6673774
# fbeta_score                               0.55634554
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-2-1-2
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-2-1-3
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                           [[0, 250233], [1, 249766]]
# roc_curve           ([0.0, 1.0, 1.0], [0.0, 0.9999959962685223, 1....
# recall                                                       0.999996
# mcc                                                       -0.00141553
# accuracy                                                     0.499532
# precision                                                    0.499533
# auc                                                          0.499998
# log_loss                                                  17.28595252
# f1_score                                                   0.66625054
# fbeta_score                                                0.55509403
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-2-1-3
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-2-2-0
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix          [[0, 124487], [0, 125513]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                    0.502052
# precision                                   0.502052
# auc                                              0.5
# log_loss                                 17.19891279
# f1_score                                  0.66848817
# fbeta_score                                0.5575813
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-2-2-0
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-2-2-1
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix            [[0, 25159], [0, 24841]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                     0.49682
# precision                                    0.49682
# auc                                              0.5
# log_loss                                 17.37962385
# f1_score                                  0.66383399
# fbeta_score                               0.55241259
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-2-2-1
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-2-2-2
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix          [[0, 125277], [0, 124723]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                    0.498892
# precision                                   0.498892
# auc                                              0.5
# log_loss                                 17.30805785
# f1_score                                  0.66568105
# fbeta_score                               0.55446097
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-2-2-2
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-2-2-3
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix          [[0, 250382], [0, 249618]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                    0.499236
# precision                                   0.499236
# auc                                              0.5
# log_loss                                 17.29617623
# f1_score                                  0.66598721
# fbeta_score                               0.55480086
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-2-2-3
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-2-3-0
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                           [[0, 124798], [1, 125201]]
# roc_curve           ([0.0, 1.0, 1.0], [0.0, 0.999992012907142, 1.0...
# recall                                                     0.99999201
# mcc                                                       -0.00199677
# accuracy                                                     0.500804
# precision                                                    0.500806
# auc                                                        0.49999601
# log_loss                                                  17.24201817
# f1_score                                                   0.66738095
# fbeta_score                                                0.55635097
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-2-3-0
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-2-3-1
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix            [[0, 25086], [0, 24914]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                     0.49828
# precision                                    0.49828
# auc                                              0.5
# log_loss                                 17.32919607
# f1_score                                  0.66513602
# fbeta_score                               0.55385614
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-2-3-1
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-2-3-2
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix                           [[0, 124974], [1, 125025]]
# roc_curve           ([0.0, 1.0, 1.0], [0.0, 0.999992001663654, 1.0...
# recall                                                       0.999992
# mcc                                                       -0.00199959
# accuracy                                                       0.5001
# precision                                                    0.500102
# auc                                                          0.499996
# log_loss                                                  17.26633404
# f1_score                                                   0.66675555
# fbeta_score                                                 0.5556558
# model                                                         xgboost
# train                                                         s-1-2-0
# valid                                                         s-2-3-2
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-2-3-3
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix          [[0, 249809], [0, 250191]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                    0.500382
# precision                                   0.500382
# auc                                              0.5
# log_loss                                 17.25659388
# f1_score                                  0.66700614
# fbeta_score                               0.55593281
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-2-3-3
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-2-4-0
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix          [[0, 124962], [0, 125038]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                    0.500152
# precision                                   0.500152
# auc                                              0.5
# log_loss                                 17.26453798
# f1_score                                  0.66680176
# fbeta_score                               0.55570567
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-2-4-0
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-2-4-1
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix            [[0, 24975], [0, 25025]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                      0.5005
# precision                                     0.5005
# auc                                              0.5
# log_loss                                 17.25251821
# f1_score                                  0.66711096
# fbeta_score                               0.55604933
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-2-4-1
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-2-4-2
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix          [[0, 125060], [0, 124940]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                     0.49976
# precision                                    0.49976
# auc                                              0.5
# log_loss                                 17.27807749
# f1_score                                   0.6664533
# fbeta_score                               0.55531851
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-2-4-2
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-2-4-3
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix          [[0, 249642], [0, 250358]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                    0.500716
# precision                                   0.500716
# auc                                              0.5
# log_loss                                 17.24505766
# f1_score                                  0.66730281
# fbeta_score                                0.5562626
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-2-4-3
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-3-1-0
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix           [[0, 191870], [0, 58130]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                     0.23252
# precision                                    0.23252
# auc                                              0.5
# log_loss                                 26.50843378
# f1_score                                  0.37730828
# fbeta_score                               0.27468269
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-3-1-0
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-3-1-1
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix            [[0, 39638], [0, 10362]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                     0.20724
# precision                                    0.20724
# auc                                              0.5
# log_loss                                 27.38159426
# f1_score                                  0.34332858
# fbeta_score                               0.24628973
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-3-1-1
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-3-1-2
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# xgboost prediction progress: |███████████████████████████████████████████████████| (done) 100%
# confusion_matrix           [[0, 192108], [0, 57892]]
# roc_curve           ([0.0, 1.0], [0.0, 1.0], [2, 1])
# recall                                           1.0
# mcc                                              0.0
# accuracy                                    0.231568
# precision                                   0.231568
# auc                                              0.5
# log_loss                                 26.54131546
# f1_score                                  0.37605394
# fbeta_score                               0.27361961
# model                                        xgboost
# train                                        s-1-2-0
# valid                                        s-3-1-2
# dtype: object
# inference  xgboost(s-1-2-0) validation set s-3-1-3
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_310/3806176547.py in <module>
#      11         valid_set = os.path.splitext(os.path.basename(csv))[0]
#      12         print("inference ","%s(%s)"%(model_name,dataset), "validation set %s"%valid_set)
# ---> 13         result = perf.Test(csv,True)
#      14         result['model'] = model_name
#      15         result['train'] = dataset
#
# /data/iot/notebook/src/inference.py in Test(self, sample_file, need_preprocess)
#     102
#     103     def Test(self , sample_file , need_preprocess = True):
# --> 104         y_true , y_pred = self.predict( sample_file , need_preprocess )
#     105         result = {}
#     106         result['confusion_matrix'] = confusion_matrix(y_true,y_pred)
#
# /data/iot/notebook/src/inference.py in predict(self, sample_file, need_preprocess)
#      78
#      79     def predict(self , sample_file , need_preprocess = True ):
# ---> 80         df = pd.read_csv(sample_file,index_col=0)
#      81         if need_preprocess:
#      82             df_all = preprocess(df)
#
# /data/iot/notebook/envs/ai/lib/python3.7/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# /data/iot/notebook/envs/ai/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     with parser:
# --> 463         return parser.read(nrows)
#     464
#     465
#
# /data/iot/notebook/envs/ai/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1050     def read(self, nrows=None):
#    1051         nrows = validate_integer("nrows", nrows)
# -> 1052         index, columns, col_dict = self._engine.read(nrows)
#    1053
#    1054         if index is None:
#
# /data/iot/notebook/envs/ai/lib/python3.7/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2054     def read(self, nrows=None):
#    2055         try:
# -> 2056             data = self._reader.read(nrows)
#    2057         except StopIteration:
#    2058             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
df_result.to_csv("%svalidation.csv"%g_analyse_path)
df_result
